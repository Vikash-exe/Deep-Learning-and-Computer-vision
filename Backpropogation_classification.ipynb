# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[9,8,1],[8,8,1],[7,6,1],[6,5,1],[5,4,0],[4,3,0]], columns=['Feature1', 'Feature2', 'Target'])

# %%
df
# Out:
#    Feature1  Feature2  Target
# 0         9         8       1
# 1         8         8       1
# 2         7         6       1
# 3         6         5       1
# 4         5         4       0
# 5         4         3       0

# %%
l = [2, 2, 1]
def initialize_parameters(l):
    x = {}
    for i in range(1, len(l)):
        print(i)
        x['W'+str(i)] = np.random.randn(l[i], l[i-1])
        # print(x['W'+str(i)])
    return x
print(initialize_parameters(l))

# %%
# Out:
# 1
# 2
# {'W1': array([[ 2.02081858,  0.07875518],
#        [ 1.62791328, -1.9189114 ]]), 'W2': array([[ 0.10888263, -0.60982686]])}
