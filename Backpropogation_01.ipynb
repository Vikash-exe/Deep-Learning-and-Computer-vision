# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame([[9,8,5],[8,8,4],[7,6,3],[6,5,2],[5,4,1],[4,3,1]], columns=['Feature1', 'Feature2', 'Target'])

# %%
df
# Out:
#    Feature1  Feature2  Target
# 0         9         8       5
# 1         8         8       4
# 2         7         6       3
# 3         6         5       2
# 4         5         4       1
# 5         4         3       1

# %%
def initialize_parameters(layer_dims):
    np.random.seed(12)
    parameters = {}
    for l in range(1, len(layer_dims)):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l], layer_dims[l-1]) * 0.1 #matrix of current layer and previous layer for weights
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1)) #matrix of current bias layer and 1 column

    return parameters

# %%
initialize_parameters([2, 2, 1])
# Out:
# {'W1': array([[ 0.04729858, -0.06814259],
#         [ 0.02424395, -0.17007356]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[ 0.07531428, -0.15347213]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):
    z = np.dot(W.T, A_prev) + b
    return z

# %%
def L_layer_forward(x,parameters):
    a = x
    l = len(parameters) // 2

    for i in range(1, l+1):
        a_prev = a
        wl = parameters['W' + str(i)]
        bl = parameters['b' + str(i)]
        print("a"+str(i-1)+ ": ", a_prev)
        print("W"+str(i)+ ": ", wl)
        print("b"+str(i)+ ": ", bl)
        print("--"*15)

        a = linear_forward(a_prev, wl, bl)
        print("a"+str(i)+ ": ", a)
        print("=="*15)

    return a, a_prev

# %%
x = df[['Feature1', 'Feature2']].values[0].reshape(2,1) # Convert to column vector
y = df['Target'].values[0].reshape(1,1) # Convert to column vector

# %%
y
# Out:
# array([[5]])

# %%
parmeters = initialize_parameters([2, 2, 1])
L_layer_forward(x, parmeters)
# Out:
# a0:  [[9]
#  [8]]
# W1:  [[ 0.04729858 -0.06814259]
#  [ 0.02424395 -0.17007356]]
# b1:  [[0.]
#  [0.]]
# ------------------------------
# a1:  [[ 0.61963885]
#  [-1.9738718 ]]
# ==============================
# a1:  [[ 0.61963885]
#  [-1.9738718 ]]
# W2:  [[ 0.07531428 -0.15347213]]
# b2:  [[0.]]
# ------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 parmeters = initialize_parameters([2, 2, 1])
# ----> 2 L_layer_forward(x, parmeters)
#
# Cell In[36], line 15, in L_layer_forward(x, parameters)
#      12 print("b"+str(i)+ ": ", bl)
#      13 print("--"*15)
# ---> 15 a = linear_forward(a_prev, wl, bl)
#      16 print("a"+str(i)+ ": ", a)
#      17 print("=="*15)
#
# Cell In[35], line 2, in linear_forward(A_prev, W, b)
#       1 def linear_forward(A_prev, W, b):
# ----> 2     z = np.dot(W.T, A_prev) + b
#       3     cache = (A_prev, W, b)
#       4     return z
#
# ValueError: shapes (2,1) and (2,1) not aligned: 1 (dim 1) != 2 (dim 0)
