# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"F:\Python\Deep-Learning-and-Computer-vision\Dataset\diabetes.csv)

# %%
df.head()
